# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakeshvd/models/blob/master/final_maskrcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-52b536ad-df27-4814-b8b4-2de26b948f05" name="files[]" multiple disabled />
#      <output id="result-52b536ad-df27-4814-b8b4-2de26b948f05">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mri_two.zip to mri_two.zip

# %%
# !unzip /content/mri_two.zip
# Out:
# Archive:  /content/mri_two.zip
#   inflating: custom.py
#    creating: customImages/train/
#   inflating: customImages/train/no10.png
#   inflating: customImages/train/no11.png
#   inflating: customImages/train/no13.png
#   inflating: customImages/train/no14.png
#   inflating: customImages/train/no15.png
#   inflating: customImages/train/no16.png
#   inflating: customImages/train/no17.png
#   inflating: customImages/train/no19.png
#   inflating: customImages/train/no2.png
#   inflating: customImages/train/no20.png
#   inflating: customImages/train/no21.png
#   inflating: customImages/train/no22.png
#   inflating: customImages/train/no23.png
#   inflating: customImages/train/no24.png
#   inflating: customImages/train/no26.png
#   inflating: customImages/train/no29.png
#   inflating: customImages/train/no3.png
#   inflating: customImages/train/no30.png
#   inflating: customImages/train/no31.png
#   inflating: customImages/train/no32.png
#   inflating: customImages/train/no35.png
# ...

# %%
# !mkdir logs

# %%
# !bash -c "mv /content/mrcnn /content/mri"

# %%
# !python  /content/mri/custom.py train --dataset=/content/mri/customImages --weights=coco
# Out:
# Using TensorFlow backend.
# Weights:  coco
# Dataset:  /content/mri/customImages
# Logs:  /logs
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                15
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# ...

# %%
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0032.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0033.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0034.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0035.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0036.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0037.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0038.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0039.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0040.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0041.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0042.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0043.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0044.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0045.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0046.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0047.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0048.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0049.h5 /content/drive/'My Drive'/coco_weights/logs"
# !bash -c "mv /logs/scan20190821T1551/mask_rcnn_scan_0050.h5 /content/drive/'My Drive'/coco_weights/logs"
